# %%
from train import experiment

# %%
exp = experiment(cuda=True)
# Out:
# /datasets/home/home-00/22/522/tiz007/val/ECE-285-MLIP-Project-B-Style-Transfer/cyclegan/utils.py:114: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data, 0.0, 0.02)

# %%
# generate Cubism style paintings
exp.test('../dataset/tests/cb/cb_test', '../dataset/tests/photo/photo_test', 'output/cubism_ckpts/netG_A2B.pth', 'output/cubism_ckpts/netG_B2A.pth', 'output/A_cb', 'output/B_cb' )
# Out:
# Generated images 0008 of 0008

# %%
# generate Monet style paintings
exp.test('../dataset/tests/monet/monet_test', '../dataset/tests/photo/photo_test', 'output/monet_ckpts/netG_A2B.pth', 'output/monet_ckpts/netG_B2A.pth', 'output/A_monet', 'output/B_monet' )
# Out:
# Generated images 0008 of 0008

# %%
# generate Pointillism style paintings
exp.test('../dataset/tests/point/point_test', '../dataset/tests/photo/photo_test', 'output/point_ckpts/netG_A2B.pth', 'output/point_ckpts/netG_B2A.pth', 'output/A_point', 'output/B_point' )
# Out:
# Generated images 0008 of 0008

# %%
# generate Van Gogh style paintings
exp.test('../dataset/tests/vg/vg_test', '../dataset/tests/photo/photo_test', 'output/vangogh_ckpts/netG_A2B.pth', 'output/vangogh_ckpts/netG_B2A.pth', 'output/A_vg', 'output/B_vg' )
# Out:
# Generated images 0008 of 0008

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
for i in range(0,4):
    
    plt.subplot(4,5,i*5+1)
    img = plt.imread('output/B_cb/real'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,i*5+2)
    img = plt.imread('output/A_vg/fake'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,i*5+3)
    img = plt.imread('output/A_monet/fake'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,i*5+4)
    img = plt.imread('output/A_cb/fake'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,i*5+5)
    img = plt.imread('output/A_point/fake'+str(i)+'.png')
    plt.imshow(img)

# %%
plt.figure(figsize=(20,10))
for i in range(4,8):
    
    plt.subplot(4,5,(i-4)*5+1)
    img = plt.imread('output/B_cb/real'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,(i-4)*5+2)
    img = plt.imread('output/A_vg/fake'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,(i-4)*5+3)
    img = plt.imread('output/A_monet/fake'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,(i-4)*5+4)
    img = plt.imread('output/A_cb/fake'+str(i)+'.png')
    plt.imshow(img)
    plt.subplot(4,5,(i-4)*5+5)
    img = plt.imread('output/A_point/fake'+str(i)+'.png')
    plt.imshow(img)
